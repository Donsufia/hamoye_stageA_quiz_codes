# %% [markdown]
# <a href="https://colab.research.google.com/github/Donsufia/hamoye_stageA_quiz_codes/blob/master/Yet_another_copy_of_My_Comprehensive_Pandas_Practice_note.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/Dataset/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding="latin-1")

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.head(20)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# ...

# %%
df["Element"]
# Out:
# 0                 Total Population - Both sexes
# 1                      Domestic supply quantity
# 2                 Food supply (kcal/capita/day)
# 3        Protein supply quantity (g/capita/day)
# 4            Fat supply quantity (g/capita/day)
#                           ...
# 60938                                      Food
# 60939       Food supply quantity (kg/capita/yr)
# 60940             Food supply (kcal/capita/day)
# 60941    Protein supply quantity (g/capita/day)
# 60942        Fat supply quantity (g/capita/day)
# Name: Element, Length: 60943, dtype: object

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df.fillna(140, inplace = True)

# %%
df.isnull().sum()
# Out:
# Area Code       0
# Area            0
# Item Code       0
# Item            0
# Element Code    0
# Element         0
# Unit            0
# Y2014           0
# Y2015           0
# Y2016           0
# Y2017           0
# Y2018           0
# dtype: int64

# %%
df.groupby("Unit").first()
# Out:
#                  Area Code     Area  Item Code                      Item  \
# Unit
# 1000 persons             4  Algeria       2501                Population
# 1000 tonnes              4  Algeria       2501                Population
# g/capita/day             4  Algeria       2901               Grand Total
# kcal/capita/day          4  Algeria       2901               Grand Total
# kg                       4  Algeria       2905  Cereals - Excluding Beer
#
#                  Element Code                                 Element  \
# Unit
# 1000 persons              511           Total Population - Both sexes
# 1000 tonnes              5301                Domestic supply quantity
# g/capita/day              674  Protein supply quantity (g/capita/day)
# kcal/capita/day           664           Food supply (kcal/capita/day)
# kg                        645     Food supply quantity (kg/capita/yr)
#
#                     Y2014     Y2015     Y2016     Y2017     Y2018
# Unit
# ...

# %%
df.groupby("Unit")["Unit"].count()
# Out:
# Unit
# 1000 persons          45
# 1000 tonnes        40933
# g/capita/day       10046
# kcal/capita/day     5014
# kg                  4905
# Name: Unit, dtype: int64

# %%
grouped_data = df.groupby("Element").agg({"Y2014" : "mean", "Y2015":"mean"})

# %%
print(grouped_data)
# Out:
#                                                Y2014         Y2015
# Element
# Domestic supply quantity                  380.762080    385.413451
# Export Quantity                            40.989246     42.552503
# Fat supply quantity (g/capita/day)          2.059529      2.057849
# Feed                                      178.394646    191.206644
# Food                                      247.616930    251.450949
# Food supply (kcal/capita/day)              91.824742     91.500101
# Food supply quantity (kg/capita/yr)        10.216179     10.142884
# Import Quantity                            55.731750     54.371505
# Losses                                     76.268293     77.371329
# Other uses (non-food)                      47.363496     39.744697
# Processing                                142.387016    144.325313
# Production                                504.252676    508.625755
# Protein supply quantity (g/capita/day)      2.384941      2.380597
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.duplicated().any()
# Out:
# False

# %%
df[["Y2014", "Y2015","Y2016","Y2017"]].corr()
# Out:
#           Y2014     Y2015     Y2016     Y2017
# Y2014  1.000000  0.994563  0.995985  0.995127
# Y2015  0.994563  1.000000  0.995653  0.987949
# Y2016  0.995985  0.995653  1.000000  0.992701
# Y2017  0.995127  0.987949  0.992701  1.000000

# %%
df.plot(kind = "scatter", x = "Y2016", y = "Y2017")
# Out:
# <Axes: xlabel='Y2016', ylabel='Y2017'>

# %%
newdf = df.filter(items =["Element","Unit", "Y2014","Y2017"]).sum()

# %%
newdf
# Out:
# Element    Total Population - Both sexesDomestic supply q...
# Unit       1000 persons1000 tonneskcal/capita/dayg/capita...
# Y2014                                             7965086.13
# Y2017                                             8375729.19
# dtype: object

# %%
df.iloc[3000]
# Out:
# Area Code                             53
# Area                               Benin
# Item Code                           2543
# Item                   Sweeteners, Other
# Element Code                        5301
# Element         Domestic supply quantity
# Unit                         1000 tonnes
# Y2014                               15.0
# Y2015                               14.0
# Y2016                               15.0
# Y2017                               15.0
# Y2018                               16.0
# Name: 3000, dtype: object

# %%
df.at[5000,"Area"]
# Out:
# 'Botswana'

# %%
df.iloc[5000]
# Out:
# Area Code                20
# Area               Botswana
# Item Code              2656
# Item                   Beer
# Element Code           5142
# Element                Food
# Unit            1000 tonnes
# Y2014                  80.0
# Y2015                  80.0
# Y2016                  83.0
# Y2017                  85.0
# Y2018                  85.0
# Name: 5000, dtype: object

# %%
A = [1,2,3,4]
B = [5,6,7,8]

# %%
A.extend(B)

# %%
A
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
df["Element"].value_counts()
# Out:
# Element
# Domestic supply quantity                  5295
# Import Quantity                           5139
# Protein supply quantity (g/capita/day)    5023
# Fat supply quantity (g/capita/day)        5023
# Food supply (kcal/capita/day)             5014
# Food                                      4941
# Food supply quantity (kg/capita/yr)       4905
# Residuals                                 4655
# Export Quantity                           4403
# Stock Variation                           4232
# Production                                3881
# Processing                                2010
# Losses                                    2009
# Other uses (non-food)                     1732
# Feed                                      1319
# Seed                                       762
# Tourist consumption                        555
# Total Population - Both sexes               45
# Name: count, dtype: int64

# %%
my_list = ["Element", "Area", "Y2015"]
for i in my_list:
  print(i)
# Out:
# Element
# Area
# Y2015

# %%
df1 = df[["Area", "Y2014"]].sort_values(by = "Y2014", ascending = False).head(5)
df1
# Out:
#            Area     Y2014
# 42973   Nigeria  176405.0
# 43129   Nigeria  109593.0
# 43133   Nigeria  108756.0
# 19008  Ethiopia   98094.0
# 16236     Egypt   90425.0

# %%
df1.plot(x= "Area", y = "Y2014", kind = "pie")
# Out:
# <Axes: ylabel='Y2014'>

# %%
df2 = df.groupby("Area")["Y2017"].max().sort_values(ascending =False)
df2
# Out:
# Area
# Nigeria                        190873.00
# Ethiopia                       106400.00
# Egypt                           96443.00
# South Africa                    57010.00
# United Republic of Tanzania     54660.00
# Mauritania                      51864.00
# Kenya                           50221.00
# Algeria                         41389.00
# Uganda                          41167.00
# Sudan                           40813.00
# Morocco                         38348.00
# Angola                          29817.00
# Ghana                           29121.00
# Mozambique                      28649.00
# Madagascar                      25571.00
# Cameroon                        24566.00
# Côte d'Ivoire                   24437.00
# Niger                           21602.00
# Burkina Faso                    19193.00
# Mali                            18512.00
# Malawi                          17670.00
# Zambia                          16854.00
# Senegal                         15419.00
# ...

# %%
sns.barplot(x = df2.index, y = df2.values)
plt.xticks(rotation = "vertical")
xlabel = None

# %%
df.head(2)
# Out:
#    Area Code     Area  Item Code        Item  Element Code  \
# 0          4  Algeria       2501  Population           511
# 1          4  Algeria       2501  Population          5301
#
#                          Element          Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes  1000 persons  38924.0  39728.0  40551.0
# 1       Domestic supply quantity   1000 tonnes      0.0      0.0      0.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0
# 1      0.0      0.0

# %%
df["Element"].value_counts()
# Out:
# Element
# Domestic supply quantity                  5295
# Import Quantity                           5139
# Protein supply quantity (g/capita/day)    5023
# Fat supply quantity (g/capita/day)        5023
# Food supply (kcal/capita/day)             5014
# Food                                      4941
# Food supply quantity (kg/capita/yr)       4905
# Residuals                                 4655
# Export Quantity                           4403
# Stock Variation                           4232
# Production                                3881
# Processing                                2010
# Losses                                    2009
# Other uses (non-food)                     1732
# Feed                                      1319
# Seed                                       762
# Tourist consumption                        555
# Total Population - Both sexes               45
# Name: count, dtype: int64

# %%
df4 = df[df["Element"].isin(["Import Quantity", "Export Quantity"])]

# %%
df4[df4["Area"]=="Nigeria"].value_counts()
# Out:
# Area Code  Area     Item Code  Item                     Element Code  Element          Unit         Y2014   Y2015    Y2016   Y2017   Y2018
# 159        Nigeria  2511       Wheat and products       5611          Import Quantity  1000 tonnes  4626.0  4413.00  4259.0  5650.0  4825.0    1
#                     2769       Aquatic Animals, Others  5611          Import Quantity  1000 tonnes  0.0     0.01     0.0     0.1     0.1       1
#                     2736       Offals, Edible           5611          Import Quantity  1000 tonnes  0.0     0.00     0.0     0.0     0.0       1
#                     2737       Fats, Animals, Raw       5611          Import Quantity  1000 tonnes  3.0     0.00     0.0     1.0     1.0       1
#                                                         5911          Export Quantity  1000 tonnes  0.0     0.00     0.0     0.0     0.0       1
# ...

# %%
df4[df4["Area"]=="Nigeria"][["Element", "Area"]].value_counts()
# Out:
# Element          Area
# Import Quantity  Nigeria    116
# Export Quantity  Nigeria    115
# Name: count, dtype: int64
